# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#import plotly.plotly as py
#import plotly.graph_objs as go

#py.offline.init_notebook_mode(connected=True)

#%matplotlib notebook
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# Out:
# /home/purna/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:38: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %%
data = pd.read_csv('Airports.csv')

# %%
data.head()
# Out:
#   Origin_airport Destination_airport    Origin_city Destination_city  \
# 0            MHK                 AMW  Manhattan, KS         Ames, IA
# 1            EUG                 RDM     Eugene, OR         Bend, OR
# 2            EUG                 RDM     Eugene, OR         Bend, OR
# 3            EUG                 RDM     Eugene, OR         Bend, OR
# 4            MFR                 RDM    Medford, OR         Bend, OR
#
#    Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 0          21     30        1       254  2008-10-01             122049
# 1          41    396       22       103  1990-11-01             284093
# 2          88    342       19       103  1990-12-01             284093
# 3          11     72        4       103  1990-10-01             284093
# 4           0     18        1       156  1990-02-01             147300
#
#    Destination_population  Org_airport_lat  Org_airport_long  \
# ...

# %%
data.tail()
# Out:
#         Origin_airport Destination_airport         Origin_city  \
# 3606798            STL                 TBN       St. Louis, MO
# 3606799            STL                 TBN       St. Louis, MO
# 3606800            STL                 TBN       St. Louis, MO
# 3606801            CGI                 TBN  Cape Girardeau, MO
# 3606802            FWA                 OH1      Fort Wayne, IN
#
#                    Destination_city  Passengers  Seats  Flights  Distance  \
# 3606798       Fort Leonard Wood, MO         281    969       51       119
# 3606799       Fort Leonard Wood, MO         245   1026       54       119
# 3606800       Fort Leonard Wood, MO         363   1273       67       119
# 3606801       Fort Leonard Wood, MO           2     19        1       146
# 3606802  Washington Court House, OH           0      0        1       135
#
#            Fly_date  Origin_population  Destination_population  \
# 3606798  2009-02-01            2828990                   46457
# ...

# %%
data.columns
# Out:
# Index(['Origin_airport', 'Destination_airport', 'Origin_city',
#        'Destination_city', 'Passengers', 'Seats', 'Flights', 'Distance',
#        'Fly_date', 'Origin_population', 'Destination_population',
#        'Org_airport_lat', 'Org_airport_long', 'Dest_airport_lat',
#        'Dest_airport_long'],
#       dtype='object')

# %%
data.shape
# Out:
# (3606803, 15)

# %% [markdown]
# so we have almost 3million which is 36 millions records with 15  columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3606803 entries, 0 to 3606802
# Data columns (total 15 columns):
# Origin_airport            object
# Destination_airport       object
# Origin_city               object
# Destination_city          object
# Passengers                int64
# Seats                     int64
# Flights                   int64
# Distance                  int64
# Fly_date                  object
# Origin_population         int64
# Destination_population    int64
# Org_airport_lat           float64
# Org_airport_long          float64
# Dest_airport_lat          float64
# Dest_airport_long         float64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 412.8+ MB

# %%
data.describe()
# Out:
#          Passengers         Seats       Flights      Distance  \
# count  3.606803e+06  3.606803e+06  3.606803e+06  3.606803e+06
# mean   2.688910e+03  4.048297e+03  3.722890e+01  6.973190e+02
# std    4.347617e+03  6.200871e+03  4.961970e+01  6.044165e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.090000e+02  1.560000e+02  2.000000e+00  2.730000e+02
# 50%    1.118000e+03  1.998000e+03  2.500000e+01  5.190000e+02
# 75%    3.503000e+03  5.370000e+03  5.500000e+01  9.270000e+02
# max    8.959700e+04  1.470620e+05  1.128000e+03  5.095000e+03
#
#        Origin_population  Destination_population  Org_airport_lat  \
# count       3.606803e+06            3.606803e+06     3.599849e+06
# mean        5.871502e+06            5.897982e+06     3.775029e+01
# std         7.858062e+06            7.906127e+06     5.765453e+00
# min         1.300500e+04            1.288700e+04     1.972140e+01
# 25%         1.030597e+06            1.025470e+06     3.363670e+01
# ...

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
data.isna().sum()
# Out:
# Origin_airport               0
# Destination_airport          0
# Origin_city                  0
# Destination_city             0
# Passengers                   0
# Seats                        0
# Flights                      0
# Distance                     0
# Fly_date                     0
# Origin_population            0
# Destination_population       0
# Org_airport_lat           6954
# Org_airport_long          6954
# Dest_airport_lat          6807
# Dest_airport_long         6807
# dtype: int64

# %%
#drop duplicates
data.duplicated().sum()
# Out:
# 41753

# %%
data = data.drop_duplicates(keep = "first")

# %%
##drop null values
data = data.dropna()

# %%
data.isna().sum()
# Out:
# Origin_airport            0
# Destination_airport       0
# Origin_city               0
# Destination_city          0
# Passengers                0
# Seats                     0
# Flights                   0
# Distance                  0
# Fly_date                  0
# Origin_population         0
# Destination_population    0
# Org_airport_lat           0
# Org_airport_long          0
# Dest_airport_lat          0
# Dest_airport_long         0
# dtype: int64

# %%
data.head()
# Out:
#   Origin_airport Destination_airport  Origin_city Destination_city  \
# 1            EUG                 RDM   Eugene, OR         Bend, OR
# 2            EUG                 RDM   Eugene, OR         Bend, OR
# 3            EUG                 RDM   Eugene, OR         Bend, OR
# 4            MFR                 RDM  Medford, OR         Bend, OR
# 5            MFR                 RDM  Medford, OR         Bend, OR
#
#    Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 1          41    396       22       103  1990-11-01             284093
# 2          88    342       19       103  1990-12-01             284093
# 3          11     72        4       103  1990-10-01             284093
# 4           0     18        1       156  1990-02-01             147300
# 5          11     18        1       156  1990-03-01             147300
#
#    Destination_population  Org_airport_lat  Org_airport_long  \
# 1                   76034        44.124599       -123.211998
# ...

# %%
data['Destination_airport'].nunique()
# Out:
# 483

# %% [markdown]
# ### datetime

# %%
data['Fly_date'] = pd.to_datetime(data['Fly_date'])

# %% [markdown]
# ### Origin Ariport

# %%
plt.figure(figsize = (12,10))
data.Origin_airport.value_counts()[:30].plot(kind = 'barh',color = 'g')
plt.xlabel("Count of Flights from Origin")
plt.ylabel("Origin Airport")
plt.title("Origin vs Count of Flights",fontsize =20, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Origin vs Count of Flights')

# %% [markdown]
# ### Destination Airport

# %%
plt.figure(figsize = (12,8))
data.Destination_airport.value_counts()[:30].plot(kind = 'bar',color = 'r')
plt.xlabel("Destination Airport")
plt.ylabel("Count of Flights from Destination")
plt.title("Destinatino vs Count of Flights",fontsize =20, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Destinatino vs Count of Flights')

# %% [markdown]
# ### Origin city

# %%
#origin city
plt.figure(figsize = (12,12))
data['Origin_city'].value_counts()[:30].plot(kind = 'barh',color = 'c')
plt.xlabel("Flights count")
plt.ylabel("Origin city")
plt.title("Origin city vs Count of Flights",fontsize =20, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Origin city vs Count of Flights')

# %% [markdown]
# ### Destination city

# %%
#Destination_city
plt.figure(figsize = (12,10))
data['Destination_city'].value_counts()[:30].plot(kind = 'barh',color = 'y')
plt.xlabel("Flights count")
plt.ylabel("Destination city")
plt.title("Destination city vs Count of Flights",fontsize =20, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Destination city vs Count of Flights')

# %% [markdown]
# ### seats

# %%
Noseat = data[['Origin_city','Destination_city','Fly_date']][data['Seats'] == 0].reset_index()

# %%
Noseat = Noseat.drop('index',axis = 1)

# %%
Noseat.drop_duplicates(inplace = True)

# %%
Noseat
# Out:
#                  Origin_city      Destination_city   Fly_date
# 0                Seattle, WA              Bend, OR 1993-09-01
# 1                Seattle, WA              Bend, OR 1997-01-01
# 2               Portland, OR              Bend, OR 2002-10-01
# 3               Portland, OR              Bend, OR 2002-12-01
# 4               Portland, OR              Bend, OR 2002-11-01
# 6               Portland, OR              Bend, OR 2003-11-01
# 7               Portland, OR              Bend, OR 2003-02-01
# 8               Portland, OR              Bend, OR 2003-08-01
# 9               Portland, OR              Bend, OR 2003-01-01
# 10              Portland, OR              Bend, OR 2003-04-01
# 11              Portland, OR              Bend, OR 2003-07-01
# 13              Portland, OR              Bend, OR 2003-09-01
# 15              Portland, OR              Bend, OR 2003-05-01
# 16              Portland, OR              Bend, OR 2003-06-01
# ...

# %% [markdown]
# **NOTE**:-
# - we have 178788 Dates with No seat avialability from 1990 to 2009.

# %% [markdown]
# ### Passengers

# %%
NoPassenger = data[['Origin_city','Destination_city','Fly_date']][data['Passengers'] == 0].reset_index().drop('index',axis = 1)

# %%
NoPassenger.drop_duplicates(inplace = True)

# %%
NoPassenger
# Out:
#                  Origin_city       Destination_city   Fly_date
# 0                Medford, OR               Bend, OR 1990-02-01
# 1                Redding, CA               Bend, OR 1993-12-01
# 2                Seattle, WA               Bend, OR 1993-09-01
# 3               Portland, OR               Bend, OR 1995-08-01
# 4               San Jose, CA               Bend, OR 1995-08-01
# 5                Medford, OR               Bend, OR 1996-01-01
# 6                Seattle, WA               Bend, OR 1997-01-01
# 7                 Eugene, OR               Bend, OR 1997-01-01
# 8        Fort Lauderdale, FL               Bend, OR 2001-11-01
# 9               Portland, OR               Bend, OR 2002-10-01
# 10              Portland, OR               Bend, OR 2002-12-01
# 11              Portland, OR               Bend, OR 2002-11-01
# 13           Great Falls, MT               Bend, OR 2003-04-01
# 14              Portland, OR               Bend, OR 2003-11-01
# ...

# %% [markdown]
# **NOTE**:-
# - We have 215179 Dates where no passengers travelled from the above Origin to Destination in 1990 to 2009.

# %% [markdown]
# ### Flights

# %%
data[data['Flights'] == data['Flights'].max()]
# Out:
#         Origin_airport Destination_airport        Origin_city  \
# 2975875            SFO                 LAX  San Francisco, CA
#
#         Destination_city  Passengers   Seats  Flights  Distance   Fly_date  \
# 2975875  Los Angeles, CA       83153  142128     1128       337 1994-12-01
#
#          Origin_population  Destination_population  Org_airport_lat  \
# 2975875            7666396                23179000        37.618999
#
#          Org_airport_long  Dest_airport_lat  Dest_airport_long
# 2975875          -122.375         33.942501        -118.407997

# %% [markdown]
# **NOTE**:-
# - we have 1128 flights on 1994-12-01 from SFO TO LAX

# %%
flights = data[['Origin_airport','Destination_airport','Fly_date','Flights']]

# %%
Morefly = flights.sort_values('Flights',ascending = False)

# %%
Morefly
# Out:
#         Origin_airport Destination_airport   Fly_date  Flights
# 2975875            SFO                 LAX 1994-12-01     1128
# 3438039            LAX                 SFO 1994-12-01     1126
# 1153503            HNL                 OGG 1994-08-01     1058
# 1643395            OGG                 HNL 1994-08-01     1056
# 1643455            OGG                 HNL 1994-12-01     1044
# 2980169            SFO                 LAX 1995-01-01     1044
# 2334133            LAX                 SAN 2001-06-01     1036
# 3438613            LAX                 SFO 1995-01-01     1036
# 3001754            SAN                 LAX 2001-06-01     1033
# 2334180            LAX                 SAN 2001-03-01     1030
# 3001939            SAN                 LAX 2001-03-01     1026
# 1153520            HNL                 OGG 1994-12-01     1022
# 3001566            SAN                 LAX 2001-07-01     1018
# 2334255            LAX                 SAN 2001-07-01     1018
# ...

# %% [markdown]
# The above table we have Flights from high to low along with its origin and destination with respect to their dates.

# %%
plt.figure(figsize = (12,6))
sns.barplot(Morefly['Flights'][:300],Morefly['Destination_airport'][:300],data = Morefly)
plt.title("top airports from")
# Out:
# Text(0.5, 1.0, 'top airports from')

# %% [markdown]
# **NOTE**:-
# - The above shows top Destination where you have morethan 800 flights from year 1990 to 2009.

# %%
Moreflights = data[['Destination_airport','Flights']][data['Flights'] >600].reset_index().drop('index',axis = 1)

# %%
Moreflights.head()
# Out:
#   Destination_airport  Flights
# 0                 ITO      730
# 1                 BOS      616
# 2                 BOS      640
# 3                 BOS      607
# 4                 BOS      606

# %%
Moreflights.Destination_airport.unique()
# Out:
# array(['ITO', 'BOS', 'DFW', 'DAL', 'ATL', 'ORD', 'HOU', 'OGG', 'OAK',
#        'PHX', 'SEA', 'ATW', 'GTR', 'HNL', 'LGA', 'PDX', 'SAV', 'CLE',
#        'SAN', 'BGM', 'EVV', 'LAX', 'SFO'], dtype=object)

# %% [markdown]
# **NOTE**:-
# - So we have More than 600 flights from the year 1990 to 2009 whichis a 19 year duration in the above shown Destination

# %%
Noflight = data[['Destination_airport','Flights','Fly_date']][data['Flights'] == data['Flights'].min()]

# %%
Noflight
# Out:
#         Destination_airport  Flights   Fly_date
# 301                     RDM        0 1993-09-01
# 508                     RDM        0 1997-01-01
# 9622                    EKO        0 2009-04-01
# 9777                    ERI        0 1990-01-01
# 10013                   ERI        0 1994-03-01
# 10614                   ERI        0 2000-03-01
# 11272                   ERI        0 2005-02-01
# 11839                   ERI        0 2009-06-01
# 13499                   ITO        0 1995-08-01
# 14086                   ITO        0 2002-10-01
# 14110                   ITO        0 2002-11-01
# 14154                   ITO        0 2002-11-01
# 14157                   ITO        0 2002-10-01
# 14160                   ITO        0 2002-12-01
# 14177                   ITO        0 2003-01-01
# 14193                   ITO        0 2003-02-01
# 14222                   ITO        0 2003-07-01
# 14444                   ITO        0 2005-12-01
# 14462                   ITO        0 2005-11-01
# ...

# %% [markdown]
# The above Destinations had no flights with respect to their Fly_date

# %%
Noflight.count()
# Out:
# Destination_airport    10761
# Flights                10761
# Fly_date               10761
# dtype: int64

# %% [markdown]
# we have 10761 records with No flights
# the above are the Destination Airports where you have no flights in the time period of 1990 to 2009

# %%
groupeddate = data.groupby(['Fly_date'])['Passengers'].sum().reset_index()

# %%
groupeddate
# Out:
#       Fly_date  Passengers
# 0   1990-01-01    27601308
# 1   1990-02-01    27006664
# 2   1990-03-01    32943339
# 3   1990-04-01    31172313
# 4   1990-05-01    31199271
# 5   1990-06-01    32899918
# 6   1990-07-01    33366406
# 7   1990-08-01    35727681
# 8   1990-09-01    28578934
# 9   1990-10-01    31288179
# 10  1990-11-01    29502236
# 11  1990-12-01    29063741
# 12  1991-01-01    27584730
# 13  1991-02-01    25954392
# 14  1991-03-01    30108344
# 15  1991-04-01    30862487
# 16  1991-05-01    31347996
# 17  1991-06-01    32319569
# 18  1991-07-01    33773277
# 19  1991-08-01    35194911
# 20  1991-09-01    28658777
# 21  1991-10-01    31457783
# 22  1991-11-01    28447588
# 23  1991-12-01    30902860
# 24  1992-01-01    26703235
# 25  1992-02-01    26254257
# 26  1992-03-01    30986146
# 27  1992-04-01    29507411
# 28  1992-05-01    31288169
# 29  1992-06-01    35902272
# ..         ...         ...
# 210 2007-07-01    54052700
# 211 2007-08-01    53557057
# ...

# %%
plt.figure(figsize = (12,8))
sns.lineplot(groupeddate['Fly_date'],groupeddate['Passengers'],data = groupeddate)
plt.title("No.of Passengers travelled in years",weight = 'bold')
plt.xlabel("Fly Dates")
plt.ylabel("No of passengers")
# Out:
# Text(0, 0.5, 'No of passengers')

# %%
groupedplace = data.groupby(['Destination_airport'])['Passengers'].sum().reset_index()

# %%
morepass = groupedplace.sort_values('Passengers',ascending = False)[:50]

# %%
plt.figure(figsize = (12,6))
sns.barplot(morepass['Destination_airport'], morepass['Passengers'],data = morepass)
plt.xticks(rotation = 90)
plt.title("No of Passengers travelled vs Destination",weight = 'bold')
plt.xlabel('Destination_airport')
plt.ylabel("No.of Passengers")
plt.show()

# %%
data
# Out:
#         Origin_airport Destination_airport         Origin_city  \
# 1                  EUG                 RDM          Eugene, OR
# 2                  EUG                 RDM          Eugene, OR
# 3                  EUG                 RDM          Eugene, OR
# 4                  MFR                 RDM         Medford, OR
# 5                  MFR                 RDM         Medford, OR
# 6                  MFR                 RDM         Medford, OR
# 7                  MFR                 RDM         Medford, OR
# 8                  MFR                 RDM         Medford, OR
# 9                  SEA                 RDM         Seattle, WA
# 10                 SEA                 RDM         Seattle, WA
# 11                 SEA                 RDM         Seattle, WA
# 12                 SEA                 RDM         Seattle, WA
# 13                 SEA                 RDM         Seattle, WA
# 14                 PDX                 RDM        Portland, OR
# ...

# %%
groupedpop = data.groupby(['Destination_airport'])['Passengers','Destination_population'].sum().reset_index()

# %%
highpop = groupedpop.sort_values('Destination_population',ascending = False)[:30]

# %%
highpop
# Out:
#     Destination_airport  Passengers  Destination_population
# 346                 ORD   528645781           2837239549664
# 251                 LAX   389469508           2000409073544
# 259                 LGA   197477266           1919021692138
# 236                 JFK   141001427           1915723299614
# 147                 EWR   209074182           1471383068122
# 118                 DFW   457457882           1113014261588
# 362                 PHL   186853894            933182429714
# 128                 DTW   251467289            880067366228
# 31                  ATL   577921368            573767951364
# 289                 MDW   118459299            499982725328
# 64                  BOS   190599518            484988182908
# 214                 IAD   107812936            467576123144
# 300                 MIA   143425239            458197565042
# 419                 SFO   242282413            452400692982
# 114                 DCA   145359149            444689333308
# ...

# %% [markdown]
# **Note**:-
# - the above shows the Total Destination population vs Passengers for every Destination airport from year 1990 to 2009.

# %%
highpop.plot(kind = 'line')

# %% [markdown]
# import plotly as py
# import plotly.graph_objs as go
# from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#
# plotly.offline.init_notebook_mode(connected=True)

# %%
sns.heatmap(data.corr())

# %% [markdown]
# ## Map in visual

# %%
flightmap = data.groupby(['Destination_airport'])['Flights'].sum().reset_index()

# %%
mapp = flightmap.sort_values('Flights',ascending = False)

# %%
mapp
# Out:
#     Destination_airport  Flights
# 346                 ORD  6884042
# 31                  ATL  6541691
# 118                 DFW  5928434
# 251                 LAX  4086399
# 128                 DTW  3447685
# 363                 PHX  3202680
# 315                 MSP  3198316
# 215                 IAH  3183004
# 443                 STL  3177228
# 94                  CLT  2836636
# 147                 EWR  2801621
# 259                 LGA  2683743
# 362                 PHL  2670572
# 415                 SEA  2575958
# 249                 LAS  2518239
# 64                  BOS  2492288
# 419                 SFO  2490455
# 106                 CVG  2285380
# 368                 PIT  2192172
# 285                 MCO  2146187
# 114                 DCA  2060266
# 91                  CLE  1849722
# 291                 MEM  1772895
# 430                 SLC  1768178
# 76                  BWI  1671146
# 214                 IAD  1664487
# 236                 JFK  1608783
# ...

# %%
# Python program to plot 
# geographical data using plotly 

# importing all necessary libraries 
import plotly.plotly as py 
import plotly.graph_objs as go 
import pandas as pd 

# some more libraries to plot graph 
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot 

# To establish connection 
init_notebook_mode(connected = True) 


# type defined is choropleth to 
# plot geographical plots 
data1 = dict(type = 'choropleth', 

# location: Arizoana, California, Newyork 
locations = list((mapp['Destination_airport'].values)[:30]),

# States of USA 
locationmode = 'ISO-3', 

# colorscale can be added as per requirement 
colorscale = 'Portland', 

# text can be given anything you like 
text = list((mapp['Destination_airport'].values)[:30]), 
z = list((mapp['Flights'].values)[:30]), 
colorbar = {'title': 'Colorbar Title Goes Here'}) 

layout = dict(geo ={'scope': 'world'}) 

# passing data dictionary as a list 
choromap = go.Figure(data = [data1], layout = layout) 

# plotting graph 
iplot(choromap)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="6f646811-3327-4e67-b624-b0e32bd1cb9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
list((mapp['Destination_airport'].values)[:])
# Out:
# ['ORD',
#  'ATL',
#  'DFW',
#  'LAX',
#  'DTW',
#  'PHX',
#  'MSP',
#  'IAH',
#  'STL',
#  'CLT',
#  'EWR',
#  'LGA',
#  'PHL',
#  'SEA',
#  'LAS',
#  'BOS',
#  'SFO',
#  'CVG',
#  'PIT',
#  'MCO',
#  'DCA',
#  'CLE',
#  'MEM',
#  'SLC',
#  'BWI',
#  'IAD',
#  'JFK',
#  'PDX',
#  'SAN',
#  'MIA',
#  'MDW',
#  'TPA',
#  'MCI',
#  'RDU',
#  'BNA',
#  'FLL',
#  'HOU',
#  'IND',
#  'MKE',
#  'OAK',
#  'SJC',
#  'MSY',
#  'DAL',
#  'CMH',
#  'HNL',
#  'SNA',
#  'AUS',
#  'SAT',
#  'ABQ',
#  'BDL',
#  'SMF',
#  'BUF',
#  'JAX',
#  'RNO',
#  'PBI',
#  'PVD',
#  'OGG',
#  'ANC',
#  'ELP',
#  'OKC',
#  'TUL',
#  'GSO',
#  'DAY',
#  'ROC',
#  'RIC',
#  'GEG',
#  'BHM',
#  'OMA',
#  'ALB',
#  'SYR',
#  'TUS',
#  'LIT',
#  'GRR',
#  'MHT',
#  'DSM',
#  'TYS',
#  'GSP',
#  'CHS',
#  'MSN',
#  'MDT',
#  'ICT',
#  'PWM',
#  'CAE',
#  'COS',
#  'JAN',
#  'SBN',
#  'SAV',
#  'LBB',
#  'FAT',
#  'LEX',
#  'PNS',
#  'HSV',
#  'FWA',
#  'ITO',
#  'CID',
#  'BTV',
#  'SHV',
#  'ABE',
#  'BTR',
#  'TLH',
# ...

# %%
mapp['Country'] = 'USA'

# %%
mapp.head()
# Out:
#     Destination_airport  Flights Country
# 346                 ORD  6884042     USA
# 31                  ATL  6541691     USA
# 118                 DFW  5928434     USA
# 251                 LAX  4086399     USA
# 128                 DTW  3447685     USA

# %%
# Python program to plot 
# geographical data using plotly 

# importing all necessary libraries 
import plotly.plotly as py 
import plotly.graph_objs as go 
import pandas as pd 

# some more libraries to plot graph 
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot 

# To establish connection 
init_notebook_mode(connected = True) 


# type defined is choropleth to 
# plot geographical plots 
data3 = dict(type = 'choropleth', 

# location: Arizoana, California, Newyork 
locations = list((mapp['Country'].values)[:]),

# States of USA 
locationmode = 'ISO-3',

# colorscale can be added as per requirement 
colorscale = 'Portland', 

# text can be given anything you like 
text = list((mapp['Destination_airport'].values)[:]), 
z = list((mapp['Flights'].values)[:]), 
colorbar = {'title': 'Colorbar Title Goes Here'}) 

layout = dict(geo ={'scope': 'usa'}) 

# passing data dictionary as a list 
choromap = go.Figure(data = [data3], layout = layout) 

# plotting graph 
iplot(choromap)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="df26915f-1354-4b22-a96c-2282177e1fae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %% [markdown]
# ### creating location codes

# %%
locationsv = ['IL','GA','TX','CA','MI','AZ','MN','TX','MO','NC','NJ','NY','PA','WA','NV','MA','CA','PA','FL','TX','OH','TN','UT','MD','VA','NY','OR','CA','FL']

# %% [markdown]
# ### creating state names

# %%
textv = ['ORD,chicago,illinois','ATL,atlanta,Geogia','DFW,dallas,Texas','Lax,Losangeles,California','DTW,Detroit,Michigan','PHX,Arizona,Arizona','MSP,Minnesota,Minnesota','IAH,Hoston,Texas','STL,st.louis,Missouri','CLT,Charlotte,Northcarolina','EWR,Newark,Newjersy','LGA,Queens,Newyork','PHL,Philadelphia,Pensilvenia','SEA,Seattle,Washington','LAS,Lasvegas,Nevada','BOS,Boston,Massachusetts','SFO,Sanfransisco,California','PIT,Pittsburgh,Pensylvania','MCO,Florida','DCA,Texas','CLE,Ohio','MEM,Tennessee','SLC,Utah','BWI,Maryland',
         'IAD,Virginia','JFK,Newyork','PDX,Oregon','SAN,California','MIA,Florida']

# %% [markdown]
# ### giving z values

# %%
val = list((mapp['Flights'].values)[:30])

# %%
 val.remove(2285380)

# %%
val
# Out:
# [6884042,
#  6541691,
#  5928434,
#  4086399,
#  3447685,
#  3202680,
#  3198316,
#  3183004,
#  3177228,
#  2836636,
#  2801621,
#  2683743,
#  2670572,
#  2575958,
#  2518239,
#  2492288,
#  2490455,
#  2192172,
#  2146187,
#  2060266,
#  1849722,
#  1772895,
#  1768178,
#  1671146,
#  1664487,
#  1608783,
#  1521446,
#  1490915,
#  1485131]

# %%
# Python program to plot 
# geographical data using plotly 

# importing all necessary libraries 
import plotly.plotly as py 
import plotly.graph_objs as go 
import pandas as pd 

# some more libraries to plot graph 
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot 

# To establish connection 
init_notebook_mode(connected = True) 

# type defined is choropleth to 
# plot geographical plots 
data4 = dict(type = 'choropleth', 

# location: Arizoana, California, Newyork 
locations = locationsv, 

# States of USA 
locationmode = 'USA-states', 

# colorscale can be added as per requirement 
colorscale = 'Portland', 

# text can be given anything you like 
text = textv,
z = val, 
colorbar = {'title': 'Flights count in 1990-2009'}) 

layout = dict(geo ={'scope': 'usa'}) 

# passing data dictionary as a list 
choromap = go.Figure(data = [data4], layout = layout) 

# plotting graph 
iplot(choromap)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="f800daf9-1e21-4ef5-8c16-407afdb67d05" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %% [markdown]
# **NOTE**:-
# - from the graph you can say that we have Illinois with highest number of flights from 1990 to 2009.

# %% [markdown]
# ## Passengers vs Seats

# %%
paseats = data.groupby(['Destination_airport'])['Passengers','Seats','Flights'].sum().reset_index()

# %%
paseats
# Out:
#     Destination_airport  Passengers      Seats  Flights
# 0                   ABE     7905895   14610367   195395
# 1                   ABI      955020    1722649    51054
# 2                   ABQ    59863229   89373700   749021
# 3                   ABR      450168     972226    32183
# 4                   ABY      613671    1149295    37402
# 5                   ACT      996181    1837414    56659
# 6                   ACV     1212761    2112655    59360
# 7                   ACY     5722248    7983532    72883
# 8                   ADM           0          0       31
# 9                   ADQ      842281    1760756    32513
# 10                  ADS           8       2535      488
# 11                  AEX     1352969    2380307    61349
# 12                  AFW       18346      28428    26474
# 13                  AGC         133        232       12
# 14                  AGS     3411867    6153162    82664
# 15                  AHN       44546     100987     6131
# ...

# %% [markdown]
# ## passenger vs year

# %%
pasyear = data.groupby(['Destination_airport','Fly_date'])['Passengers','Seats','Flights'].sum().reset_index()

# %%
pasyear
# Out:
#       Destination_airport   Fly_date  Passengers  Seats  Flights
# 0                     ABE 1990-01-01       27207  61183      625
# 1                     ABE 1990-02-01       26956  56197      566
# 2                     ABE 1990-03-01       32797  62214      628
# 3                     ABE 1990-04-01       31017  60355      604
# 4                     ABE 1990-05-01       33021  61967      653
# 5                     ABE 1990-06-01       33908  61024      642
# 6                     ABE 1990-07-01       33327  61219      674
# 7                     ABE 1990-08-01       36740  65829      685
# 8                     ABE 1990-09-01       28155  60169      616
# 9                     ABE 1990-10-01       33766  62869      661
# 10                    ABE 1990-11-01       30176  58842      611
# 11                    ABE 1990-12-01       25638  56525      581
# 12                    ABE 1991-01-01       22566  56132      598
# ...

# %%
abe90_09 = pasyear[pasyear['Destination_airport'] == 'ABE']

# %%
abe90_09
# Out:
#     Destination_airport   Fly_date  Passengers  Seats  Flights
# 0                   ABE 1990-01-01       27207  61183      625
# 1                   ABE 1990-02-01       26956  56197      566
# 2                   ABE 1990-03-01       32797  62214      628
# 3                   ABE 1990-04-01       31017  60355      604
# 4                   ABE 1990-05-01       33021  61967      653
# 5                   ABE 1990-06-01       33908  61024      642
# 6                   ABE 1990-07-01       33327  61219      674
# 7                   ABE 1990-08-01       36740  65829      685
# 8                   ABE 1990-09-01       28155  60169      616
# 9                   ABE 1990-10-01       33766  62869      661
# 10                  ABE 1990-11-01       30176  58842      611
# 11                  ABE 1990-12-01       25638  56525      581
# 12                  ABE 1991-01-01       22566  56132      598
# 13                  ABE 1991-02-01       20113  44630      468
# ...

# %% [markdown]
# # Forecasting passenger traffic

# %% [markdown]
# **Lets take the only airport data with Airport code ABE**.

# %%
ane = data[data['Destination_airport'] == 'ABE']

# %%
ane
# Out:
#         Origin_airport Destination_airport    Origin_city Destination_city  \
# 1888387            BWI                 ABE  Baltimore, MD    Allentown, PA
# 1888388            BWI                 ABE  Baltimore, MD    Allentown, PA
# 1888389            BWI                 ABE  Baltimore, MD    Allentown, PA
# 1888390            BWI                 ABE  Baltimore, MD    Allentown, PA
# 1888391            BWI                 ABE  Baltimore, MD    Allentown, PA
# 1888392            BWI                 ABE  Baltimore, MD    Allentown, PA
# 1888393            CLE                 ABE  Cleveland, OH    Allentown, PA
# 1888394            BWI                 ABE  Baltimore, MD    Allentown, PA
# 1888395            BWI                 ABE  Baltimore, MD    Allentown, PA
# 1888396            BWI                 ABE  Baltimore, MD    Allentown, PA
# 1888397            BWI                 ABE  Baltimore, MD    Allentown, PA
# ...

# %%
anee  = ane.groupby(['Fly_date'])['Passengers'].sum().reset_index()

# %%
anee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 2 columns):
# Fly_date      240 non-null datetime64[ns]
# Passengers    240 non-null int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 3.8 KB

# %%
anee = anee.set_index('Fly_date')

# %%
anee
# Out:
#             Passengers
# Fly_date
# 1990-01-01       27207
# 1990-02-01       26956
# 1990-03-01       32797
# 1990-04-01       31017
# 1990-05-01       33021
# 1990-06-01       33908
# 1990-07-01       33327
# 1990-08-01       36740
# 1990-09-01       28155
# 1990-10-01       33766
# 1990-11-01       30176
# 1990-12-01       25638
# 1991-01-01       22566
# 1991-02-01       20113
# 1991-03-01       22095
# 1991-04-01       24315
# 1991-05-01       29120
# 1991-06-01       30329
# 1991-07-01       34925
# 1991-08-01       36039
# 1991-09-01       32134
# 1991-10-01       35966
# 1991-11-01       31695
# 1991-12-01       32080
# 1992-01-01       24628
# 1992-02-01       24666
# 1992-03-01       28997
# 1992-04-01       27641
# 1992-05-01       31645
# 1992-06-01       37062
# ...                ...
# 2007-07-01       37836
# 2007-08-01       37796
# 2007-09-01       31429
# 2007-10-01       36154
# 2007-11-01       34155
# 2007-12-01       31468
# 2008-01-01       27302
# ...

# %%
anee.plot(figsize = (12,6))
plt.title("Time series of Total Passengers 1990 to 2009",weight = 'bold')
plt.xlabel('Years',fontsize = 13)
plt.ylabel('Population count',fontsize = 13)
# Out:
# Text(0, 0.5, 'Population count')

# %% [markdown]
# **Time series Decomposition**:- time-series decomposition that allows us to decompose our time series into three distinct components:
#
# - trend
# - seasonality
# - noise.

# %%
import statsmodels.api as sm

from pylab import rcParams
rcParams['figure.figsize'] = 18, 8

decomposition = sm.tsa.seasonal_decompose(anee, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# #### ARIMA -Autoregressive Integrated Moving Average.
#
# - ARIMA models are denoted with the notation **ARIMA(p, d, q)**.
# - These three parameters account for seasonality, trend, and noise in data.

# %%
import itertools
#all the three variables will have the same range.
p = d = q = range(0, 3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 0, 2, 12)
# SARIMAX: (0, 0, 2) x (0, 1, 0, 12)
# SARIMAX: (0, 0, 2) x (0, 1, 1, 12)

# %% [markdown]
# use a **“grid search”** to find the optimal set of parameters that yields the best performance for our model.

# %% [markdown]
# fdssdsdfa
# for param in pdq:
#     for param_seasonal in seasonal_pdq:
#         try:
#             mod = sm.tsa.statespace.SARIMAX(anee,
#                                             order=param,
#                                             seasonal_order=param_seasonal,
#                                             enforce_stationarity=False,
#                                             enforce_invertibility=False)
#
#             results = mod.fit()
#
#             print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
#         except:
#             continue

# %% [markdown]
# - The above output suggests that **SARIMA(1, 2, 2)x(0, 2, 2, 12)12** yields the lowest AIC value of AIC:3544.
# - Using AIC to Test ARIMA Models. The **Akaike Information Critera (AIC)** is a widely used measure of a statistical model. It basically quantifies
#  - the goodness of fit
#  - the simplicity/parsimony, of the model into a single statistic.
#  - When comparing two models, the one with the lower AIC is generally “better”
# - Therefore we should consider this to be optimal option.

# %%
mod = sm.tsa.statespace.SARIMAX(anee,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2072      1.005     -0.206      0.837      -2.177       1.763
# ma.L1          0.0981      1.020      0.096      0.923      -1.900       2.096
# ar.S.L12      -0.5150      0.055     -9.285      0.000      -0.624      -0.406
# sigma2       1.16e+07   7.75e+05     14.969      0.000    1.01e+07    1.31e+07
# ...

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2004-01-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = anee['1990':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Years')
ax.set_ylabel('Count of Passengers')
plt.title('validating forecast in observed vs forecast')
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = anee['2004-01-01':]

# %%
def mean_absolute_percentage_error(y_forecasted , y_truth): 
    y_true, y_pred = np.array(y_forecasted), np.array(y_truth)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(y_forecasted , y_truth)
# Out:
# 17.919315883581234

# %% [markdown]
# ### Producing and visualizing forecasts

# %%
pred_uc = results.get_forecast(steps=50)
pred_ci = pred_uc.conf_int()
ax = anee.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
plt.ylim(10000,50000)
plt.title("forecasting future Passengers",weight  = 'bold')
ax.set_xlabel('Year')
ax.set_ylabel('Passengers count')
plt.legend()
plt.show()

# %%
print('forecasted values of Average predicted Delay in minutes values')
final=pd.DataFrame(pred_uc.predicted_mean)
final=final.reset_index()
final.columns = ['Date','No of Passengers']
final
# Out:
# forecasted values of Average predicted Delay in minutes values
#          Date  No of Passengers
# 0  2010-01-01      24109.772558
# 1  2010-02-01      25066.352078
# 2  2010-03-01      31106.476162
# 3  2010-04-01      30644.526712
# 4  2010-05-01      30741.768749
# 5  2010-06-01      32759.858987
# 6  2010-07-01      35702.070083
# 7  2010-08-01      33806.200267
# 8  2010-09-01      26114.258277
# 9  2010-10-01      29452.878442
# 10 2010-11-01      27060.266280
# 11 2010-12-01      26611.839422
# 12 2011-01-01      22437.848778
# 13 2011-02-01      22924.486962
# 14 2011-03-01      29034.581617
# 15 2011-04-01      28892.395878
# 16 2011-05-01      29224.334729
# 17 2011-06-01      30859.763718
# 18 2011-07-01      36226.809581
# 19 2011-08-01      33548.649507
# 20 2011-09-01      25811.361224
# 21 2011-10-01      29085.807072
# 22 2011-11-01      27102.902814
# 23 2011-12-01      26316.367492
# 24 2012-01-01      22140.195069
# 25 2012-02-01      22868.833928
# ...

# %% [markdown]
# # forecating Flight Arrival

# %%
abefly  = ane.groupby(['Fly_date'])['Flights'].sum().reset_index()

# %%
abefly = abefly.set_index('Fly_date')

# %%
abefly
# Out:
#             Flights
# Fly_date
# 1990-01-01      625
# 1990-02-01      566
# 1990-03-01      628
# 1990-04-01      604
# 1990-05-01      653
# 1990-06-01      642
# 1990-07-01      674
# 1990-08-01      685
# 1990-09-01      616
# 1990-10-01      661
# 1990-11-01      611
# 1990-12-01      581
# 1991-01-01      598
# 1991-02-01      468
# 1991-03-01      498
# 1991-04-01      509
# 1991-05-01      606
# 1991-06-01      586
# 1991-07-01      765
# 1991-08-01      774
# 1991-09-01      760
# 1991-10-01      794
# 1991-11-01      770
# 1991-12-01      804
# 1992-01-01      636
# 1992-02-01      604
# 1992-03-01      646
# 1992-04-01      642
# 1992-05-01      623
# 1992-06-01      611
# ...             ...
# 2007-07-01      974
# 2007-08-01     1001
# 2007-09-01      913
# 2007-10-01     1003
# 2007-11-01      945
# 2007-12-01      904
# 2008-01-01      877
# 2008-02-01      811
# 2008-03-01      869
# 2008-04-01      895
# 2008-05-01      878
# 2008-06-01      926
# ...

# %%
abefly.plot(figsize = (12,6))
plt.title("Time series of Total Passengers 1990 to 2009",weight = 'bold')
plt.xlabel('Years',fontsize = 13)
plt.ylabel('Flights count',fontsize = 13)
# Out:
# Text(0, 0.5, 'Flights count')

# %%
import statsmodels.api as sm

from pylab import rcParams
rcParams['figure.figsize'] = 18, 8

decomposition = sm.tsa.seasonal_decompose(abefly, model='additive')
fig = decomposition.plot()
plt.show()

# %%
import itertools
#all the three variables will have the same range.
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %% [markdown]
# use a **“grid search”** to find the optimal set of parameters that yields the best performance for our model.

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(abefly,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:3905.489114692852
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:3482.626374669667
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:3029.8952794986617
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:2871.329554489381
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:3042.86469211395
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:3025.9017360564158
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:2883.949837591007
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:2873.3046968955086
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:3588.799641357895
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:3209.834850683763
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:2839.8023793425346
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:2678.056299022729
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:2863.492363930735
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:2826.1967345198204
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:2702.7003634214707
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:2680.0559189297737
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:2771.1629736828204
# ...

# %% [markdown]
# **ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:2422.860299175615**
# is best.

# %%
mod = sm.tsa.statespace.SARIMAX(abefly,
                                order=(0, 1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0664      0.086     -0.770      0.441      -0.235       0.103
# ma.S.L12      -1.1648      0.064    -18.169      0.000      -1.290      -1.039
# sigma2      3502.2453    376.723      9.297      0.000    2763.882    4240.609
# ...

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
pred

# %%
pred.predicted_mean
# Out:
# 2004-01-01    32715.522681
# 2004-02-01    33319.226759
# 2004-03-01    40442.696041
# 2004-04-01    39666.777888
# 2004-05-01    46063.345248
# 2004-06-01    43020.015301
# 2004-07-01    40943.734215
# 2004-08-01    44115.717571
# 2004-09-01    33126.978380
# 2004-10-01    40895.524942
# 2004-11-01    40911.212217
# 2004-12-01    33467.670076
# 2005-01-01    23791.784492
# 2005-02-01    26227.811181
# 2005-03-01    34932.760104
# 2005-04-01    34016.777792
# 2005-05-01    41816.749425
# 2005-06-01    37969.253382
# 2005-07-01    40123.592542
# 2005-08-01    40237.829277
# 2005-09-01    26072.076283
# 2005-10-01    39558.113396
# 2005-11-01    27401.970440
# 2005-12-01    29308.681104
# 2006-01-01    25829.800148
# 2006-02-01    29299.863525
# 2006-03-01    35587.091407
# 2006-04-01    34105.719170
# 2006-05-01    32988.305042
# 2006-06-01    32807.487185
#                   ...
# 2007-07-01    36819.016732
# 2007-08-01    36238.120639
# 2007-09-01    29330.841461
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2004-01-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = abefly['1990':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Years')
ax.set_ylabel('Count of Passengers')
plt.title('validating forecast in observed vs forecast')
plt.legend()
plt.show()

# %%
y_forecasted1 = pred.predicted_mean
y_truth1 = abefly['2004-01-01':]

# %%
def mean_absolute_percentage_error(y_forecasted1 , y_truth1): 
    y_true, y_pred = np.array(y_forecasted1), np.array(y_truth1)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(y_forecasted1 , y_truth1)
# Out:
# 22.85700545765735

# %% [markdown]
# ### Producing and visualizing forecasts

# %%
pred_uc = results.get_forecast(steps=40)
pred_ci = pred_uc.conf_int()
ax = abefly.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
#plt.ylim(10000,50000)
plt.title("forecasting future Passengers",weight  = 'bold')
ax.set_xlabel('Year')
ax.set_ylabel('Passengers count')
plt.legend()
plt.show()

# %%
print('forecasted values of Average predicted Delay in minutes values')
final=pd.DataFrame(pred_uc.predicted_mean)
final=final.reset_index()
final.columns = ['Date','No of Flights']
final['No of Flights'] = final['No of Flights'].astype(int)
final
# Out:
# forecasted values of Average predicted Delay in minutes values
#          Date  No of Flights
# 0  2010-01-01            685
# 1  2010-02-01            620
# 2  2010-03-01            707
# 3  2010-04-01            693
# 4  2010-05-01            717
# 5  2010-06-01            718
# 6  2010-07-01            750
# 7  2010-08-01            757
# 8  2010-09-01            658
# 9  2010-10-01            758
# 10 2010-11-01            695
# 11 2010-12-01            692
# 12 2011-01-01            656
# 13 2011-02-01            592
# 14 2011-03-01            679
# 15 2011-04-01            664
# 16 2011-05-01            688
# 17 2011-06-01            689
# 18 2011-07-01            721
# 19 2011-08-01            728
# 20 2011-09-01            630
# 21 2011-10-01            729
# 22 2011-11-01            667
# 23 2011-12-01            663
# 24 2012-01-01            628
# 25 2012-02-01            563
# 26 2012-03-01            650
# 27 2012-04-01            636
# 28 2012-05-01            659
# ...
